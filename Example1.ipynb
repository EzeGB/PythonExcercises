# %% [markdown]
# <a href="https://colab.research.google.com/github/EzeGB/PythonExcercises/blob/dev/Example1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Example 1**
#
# This a Python basic excercises dossier.

# %%
a = 5
b = 2

c = a + b
d = a - b
e = a * b
f = a / b
g = a // b
h = a % b

print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(g)
print(h)
print('I write: ',(a*b/(a-b)))

# %% [markdown]
# Excersise 1.
# Define three variables: c, d, e, having values of 10, 20 and 30 respectively.
# Show these variable values on screen.

# %%
c = 10
d = 20
e = 30
print ('Variable C:',c)
print ('Variable D:',d)
print ('Variable E:',e)
# Out:
# Variable C: 10
# Variable D: 20
# Variable E: 30
