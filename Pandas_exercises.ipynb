# %% [markdown]
# <a href="https://colab.research.google.com/github/EzeGB/PythonExcercises/blob/pandazosact/Pandas_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(data = [[61,70,55],
                          [48,42,75],
                          [15,75,58],
                          [35,40,22]],
                  columns = ['Primer parcial','Segundo parcial','Tercer parcial']
                  )
df.head(2)
# Out:
#    Primer parcial  Segundo parcial  Tercer parcial
# 0              61               70              55
# 1              48               42              75

# %%
df.tail(3)
# Out:
#    Primer parcial  Segundo parcial  Tercer parcial
# 1              48               42              75
# 2              15               75              58
# 3              35               40              22

# %% [markdown]
# ##Exercise
# Add 7 rows to the dataFrame

# %%
df = pd.DataFrame(data = [[61,70,55],
                          [48,42,75],
                          [15,75,58],
                          [35,40,22],
                          #------------#
                          [100,100,100],
                          [1,1,1],
                          [51,51,51],
                          [70,70,70],
                          [51,100,70],
                          [28,100,45],
                          [68,89,49]],
                  columns = ['Primer parcial','Segundo parcial','Tercer parcial']
                  )

# %%
df_1p = df['Primer parcial']
df_1p
# Out:
# 0      61
# 1      48
# 2      15
# 3      35
# 4     100
# 5       1
# 6      51
# 7      70
# 8      51
# 9      28
# 10     68
# Name: Primer parcial, dtype: int64

# %%
df_prim_seg_mt = df[['Primer parcial','Segundo parcial']]
df_prim_seg_mt.head(5)
# Out:
#    Primer parcial  Segundo parcial
# 0              61               70
# 1              48               42
# 2              15               75
# 3              35               40
# 4             100              100

# %%
df_prim_seg_mt.to_csv('Primer y segundo parcial.csv',index=False)

# %%
df_employees = pd.read_csv('empleadosCSV.csv')
df_employees.head(30)
# Out:
#     id     nombre   apellido sexo fecha_nacimiento fecha_incorporacion  \
# 0    1       Juan      Pérez    M       1985-03-15          2015-06-01
# 1    2      María   González    F       1990-07-22          2018-03-15
# 2    3     Carlos  Rodríguez    M       1988-11-30          2016-09-01
# 3    4        Ana   Martínez    M       1992-05-10          2019-01-20
# 4    5       Luis      López    M       1987-09-05          2014-11-15
# 5    6     Carmen    Sánchez    F       1991-02-28          2017-04-10
# 6    7      Pedro    Ramírez    M       2018-12-18          2013-07-25
# 7    8      Laura     Torres    M       15/08/1993          2020-02-14
# 8    9      Diego     Flores    M       1989-04-25          2016-12-01
# 9   10      Sofia     Rivera    F       1994-10-12          2021-05-18
# 10  11     Miguel      Gómez    M       1984-06-08          2012-03-20
# 11  12  Valentina       Díaz  NaN       1995-01-30          2022-08-01
# ...

# %%
df_employees.columns
# Out:
# Index(['id', 'nombre', 'apellido', 'sexo', 'fecha_nacimiento',
#        'fecha_incorporacion', 'fecha_salida', 'salario_base'],
#       dtype='object')

# %%
df_employees.dtypes
# Out:
# id                       int64
# nombre                  object
# apellido                object
# sexo                    object
# fecha_nacimiento        object
# fecha_incorporacion     object
# fecha_salida            object
# salario_base           float64
# dtype: object

# %%
df_employees[['nombre','apellido']].head(5)
# Out:
#    nombre   apellido
# 0    Juan      Pérez
# 1   María   González
# 2  Carlos  Rodríguez
# 3     Ana   Martínez
# 4    Luis      López

# %% [markdown]
# ##Exercise
# Get the empleadoCSV registers, where the sex is F and salary is between 4000 and 6000(inclusive)

# %%
df_filter = df_employees [(df_employees['sexo']=='F') & (df_employees['salario_base'] >= 4000) & (df_employees['salario_base'] <= 6000)]
df_filter[['nombre','apellido']].head(10)
# Out:
#       nombre  apellido
# 1      María  González
# 5     Carmen   Sánchez
# 13  Isabella   Jiménez
# 19  Gabriela     Rojas
# 23   Natalia   Mendoza
# 25  Carolina     Reyes
# 29    Renata   Aguilar
# 33   Adriana   Estrada
# 37   Mariana      León
# 39     Elena      Peña

# %%
df_employees['sexo'] = df_employees['sexo'].fillna('No consignado')
df_employees.head(20)
# Out:
#     id     nombre   apellido           sexo fecha_nacimiento  \
# 0    1       Juan      Pérez              M       1985-03-15
# 1    2      María   González              F       1990-07-22
# 2    3     Carlos  Rodríguez              M       1988-11-30
# 3    4        Ana   Martínez              M       1992-05-10
# 4    5       Luis      López              M       1987-09-05
# 5    6     Carmen    Sánchez              F       1991-02-28
# 6    7      Pedro    Ramírez              M       2018-12-18
# 7    8      Laura     Torres              M       15/08/1993
# 8    9      Diego     Flores              M       1989-04-25
# 9   10      Sofia     Rivera              F       1994-10-12
# 10  11     Miguel      Gómez              M       1984-06-08
# 11  12  Valentina       Díaz  No consigando       1995-01-30
# 12  13     Andrés    Morales              M       1990-08-14
# 13  14   Isabella    Jiménez              F       1993-03-22
# ...

# %%
df_employees['salario_base'].mean()
# Out:
# np.float64(4698.989898989899)

# %% [markdown]
# ##exercise
# 1. impute values in column salario_base with 0
# 2. impute values in column salario_base with the mean

# %%
df_employees0 = pd.read_csv('empleadosCSV.csv')
df_employeesM = pd.read_csv('empleadosCSV.csv')

df_employees0['salario_base'] = df_employees0['salario_base'].fillna(0)
df_employeesM['salario_base'] = df_employeesM['salario_base'].fillna(df_employees['salario_base'].mean())

df_employees0.head(20)
# Out:
#     id     nombre   apellido sexo fecha_nacimiento fecha_incorporacion  \
# 0    1       Juan      Pérez    M       1985-03-15          2015-06-01
# 1    2      María   González    F       1990-07-22          2018-03-15
# 2    3     Carlos  Rodríguez    M       1988-11-30          2016-09-01
# 3    4        Ana   Martínez    M       1992-05-10          2019-01-20
# 4    5       Luis      López    M       1987-09-05          2014-11-15
# 5    6     Carmen    Sánchez    F       1991-02-28          2017-04-10
# 6    7      Pedro    Ramírez    M       2018-12-18          2013-07-25
# 7    8      Laura     Torres    M       15/08/1993          2020-02-14
# 8    9      Diego     Flores    M       1989-04-25          2016-12-01
# 9   10      Sofia     Rivera    F       1994-10-12          2021-05-18
# 10  11     Miguel      Gómez    M       1984-06-08          2012-03-20
# 11  12  Valentina       Díaz  NaN       1995-01-30          2022-08-01
# ...

# %%
df_employeesM.head(20)
# Out:
#     id     nombre   apellido sexo fecha_nacimiento fecha_incorporacion  \
# 0    1       Juan      Pérez    M       1985-03-15          2015-06-01
# 1    2      María   González    F       1990-07-22          2018-03-15
# 2    3     Carlos  Rodríguez    M       1988-11-30          2016-09-01
# 3    4        Ana   Martínez    M       1992-05-10          2019-01-20
# 4    5       Luis      López    M       1987-09-05          2014-11-15
# 5    6     Carmen    Sánchez    F       1991-02-28          2017-04-10
# 6    7      Pedro    Ramírez    M       2018-12-18          2013-07-25
# 7    8      Laura     Torres    M       15/08/1993          2020-02-14
# 8    9      Diego     Flores    M       1989-04-25          2016-12-01
# 9   10      Sofia     Rivera    F       1994-10-12          2021-05-18
# 10  11     Miguel      Gómez    M       1984-06-08          2012-03-20
# 11  12  Valentina       Díaz  NaN       1995-01-30          2022-08-01
# ...

# %%
df_position = pd.DataFrame(data=[[1,'accountant'],
                                 [3,'administrator'],
                                 [15,'manager'],
                                 [86,'secretary'],
                                 [100,'human resources']],
                           columns = ['empleado','cargo'])
df_position
# Out:
#    empleado            cargo
# 0         1       accountant
# 1         3    administrator
# 2        15          manager
# 3        86        secretary
# 4       100  human resources

# %% [markdown]
# ##MERGE as SQL join equivalent

# %%
df_join = pd.merge(df_employees,df_position, left_on = ['id'], right_on= ['empleado'])
df_join[['nombre','apellido','salario_base','cargo']]
# Out:
#       nombre    apellido  salario_base            cargo
# 0       Juan       Pérez        4500.0       accountant
# 1     Carlos   Rodríguez        4800.0    administrator
# 2    Roberto   Hernández        5100.0          manager
# 3    Yessica     Urrutia        4350.0        secretary
# 4  Constanza  Norambuena           NaN  human resources

# %% [markdown]
# Assign jobs to 5 more employees

# %%
df_position2 = pd.DataFrame(data=[[1,'accountant'],
                                 [3,'administrator'],
                                 [15,'manager'],
                                 [86,'secretary'],
                                 [100,'human resources'],
                                 [2,'marketing'],
                                 [19,'janitor'],
                                 [31,'finances'],
                                 [97,'director'],
                                 [99,'jury']],
                           columns = ['empleado_id','cargo'])
df_position
# Out:
#    empleado            cargo
# 0         1       accountant
# 1         3    administrator
# 2        15          manager
# 3        86        secretary
# 4       100  human resources
# 5         2        marketing
# 6        19          janitor
# 7        31         finances
# 8        97         director
# 9        99             jury

# %%
df_join = pd.merge(df_employeesM,df_position2, how='left', left_on = ['id'], right_on= ['empleado_id'], indicator=True)
df_join[['nombre','apellido','salario_base','cargo','_merge']]
# Out:
#        nombre    apellido  salario_base            cargo     _merge
# 0        Juan       Pérez   4500.000000       accountant       both
# 1       María    González   5200.000000        marketing       both
# 2      Carlos   Rodríguez   4800.000000    administrator       both
# 3         Ana    Martínez   4100.000000              NaN  left_only
# 4        Luis       López   5500.000000              NaN  left_only
# ..        ...         ...           ...              ...        ...
# 95      Paola     Órdenes   3850.000000              NaN  left_only
# 96    Gustavo   Espíndola   4700.000000         director       both
# 97   Victoria       Olave   4550.000000              NaN  left_only
# 98   Bernardo      Quiroz   5200.000000             jury       both
# 99  Constanza  Norambuena   4698.989899  human resources       both
#
# [100 rows x 5 columns]

# %% [markdown]
# ## pick only those who dont have a job

# %%
df_refilter = df_join[df_join['_merge'] == 'left_only']
df_refilter
# Out:
#     id    nombre  apellido sexo fecha_nacimiento fecha_incorporacion  \
# 3    4       Ana  Martínez    M       1992-05-10          2019-01-20
# 4    5      Luis     López    M       1987-09-05          2014-11-15
# 5    6    Carmen   Sánchez    F       1991-02-28          2017-04-10
# 6    7     Pedro   Ramírez    M       2018-12-18          2013-07-25
# 7    8     Laura    Torres    M       15/08/1993          2020-02-14
# ..  ..       ...       ...  ...              ...                 ...
# 92  93   Enrique     Yáñez    M       1989-03-14          2017-05-19
# 93  94    Jazmín    Montes    M       1991-10-08          2018-11-30
# 94  95     Ramón      Mena    M       1986-06-20          2014-07-25
# 95  96     Paola   Órdenes    F       1993-09-23          2020-08-14
# 97  98  Victoria     Olave    F       1990-07-07          2017-08-11
#
#    fecha_salida  salario_base  empleado_id cargo     _merge
# 3           NaN        4100.0          NaN   NaN  left_only
# ...
